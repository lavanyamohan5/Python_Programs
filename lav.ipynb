# %%
import matplotlib.pyplot as plt
x = [1, 2, 3, 4, 5]
y = [2, 4, 6, 8, 10]
plt.plot(x, y, marker='o', linestyle='-', color='b')
plt.xlabel('X Axis')
plt.ylabel('Y Axis')
plt.title('Simple Line Plot')
plt.show()

# %%
import matplotlib.pyplot as plt

categories = ['Apple', 'Banana', 'Orange', 'Guava', 'Pomegranate']
values = [10, 15, 7, 12, 9]

plt.bar(categories, values, color='skyblue')
plt.xlabel('Fruits')
plt.ylabel('Quantity')
plt.title('Fruit Quantity Bar Chart')
plt.show()

# %%
import matplotlib.pyplot as plt

x = [1, 2, 3, 4, 5]
y = [2, 4, 5, 7, 6]

plt.scatter(x, y, color='green')
plt.xlabel('X Axis')
plt.ylabel('Y Axis')
plt.title('Simple Scatter Plot')
plt.show()

# %%
import matplotlib.pyplot as plt

x1 = [1, 2, 3, 4, 5]
y1 = [2, 4, 5, 7, 6]

x2 = [1, 2, 3, 4, 5]
y2 = [3, 5, 6, 8, 7]

plt.scatter(x1, y1, color='blue')
plt.scatter(x2, y2, color='red')

plt.xlabel('X Axis')
plt.ylabel('Y Axis')
plt.title('Scatter Plot for Two Groups')
plt.show()

# %%
import matplotlib.pyplot as plt

x1 = [1, 2, 3, 4, 5]
y1 = [2, 4, 5, 7, 6]

x2 = [1, 2, 3, 4, 5]
y2 = [3, 5, 6, 8, 7]

plt.scatter(x1, y1, color='blue', label='Group 1')
plt.scatter(x2, y2, color='red', label='Group 2')

plt.xlabel('X Axis')
plt.ylabel('Y Axis')
plt.title('Scatter Plot for Two Groups')
plt.legend()
plt.grid(True)

plt.show()
